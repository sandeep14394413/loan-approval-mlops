# %% [markdown]
# # Loan Approval — Exploratory Data Analysis
#
# Use this notebook for initial exploration.
# Keep production logic in the `src/` modules.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../data/raw/applicant-details-for-loan-approve.csv')
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isnull().sum()

# %%
df['Loan_Status'].value_counts().plot(kind='bar')
plt.title('Loan Approval Distribution')
plt.show()
